# %%
from ultralytics import YOLO

# %%
trained_model = YOLO(r'/Users/pratyushmohanty/Downloads/brain-tumor/runs/detect/train/weights/best.pt')
results = trained_model(r'/Users/pratyushmohanty/Downloads/brain-tumor/image4.jpeg')
# Out:
# image 1/1 /Users/pratyushmohanty/Downloads/brain-tumor/image4.jpeg: 224x640 4 negatives, 7 positives, 34.5ms
# Speed: 0.9ms preprocess, 34.5ms inference, 0.7ms postprocess per image at shape (1, 3, 224, 640)

# %%
import matplotlib.pyplot as plt
from PIL import Image
# Ensure matplotlib inline mode
# %matplotlib inline
# Assuming results[0].plot() returns an array
image_array = results[0].plot()

# Display the image
plt.imshow(image_array)
plt.axis('off')  # Hide axes
plt.show()
